# %%
import numpy as np
from skimage import io

# %%
l=np.array([1,2,3])
print(type(l))
print(l[0])
print(l.shape)
matrix = np.array([[1,2],[3,4]])
print(matrix.shape[0])
# Out:
# <class 'numpy.ndarray'>
# 1
# (3,)
# 2

# %%
zero = np.zeros((2,2))
print(zero)
# Out:
# [[0. 0.]
#  [0. 0.]]

# %%
first5=np.arange(1,6)
print(first5)
# Out:
# [1 2 3 4 5]

# %%
new_matrix = np.full((2,2),8)
print(new_matrix)
# Out:
# [[8 8]
#  [8 8]]

# %%
randoms = np.random.random((2,3))
print(randoms)
# Out:
# [[0.72052779 0.68298753 0.68210544]
#  [0.56391006 0.738028   0.70592594]]

# %%
gauss = np.random.normal(0,0.1,(2,3))
print(gauss)
# Out:
# [[-0.04142127  0.09095174 -0.00159122]
#  [-0.15510279  0.10887979  0.10279005]]

# %%
l=np.array([1,2,3,4])
print(l>2)
# Out:
# [False False  True  True]

# %%
print(l[l>2])
# Out:
# [3 4]

# %%
l1 = np.array([[3,4],[5,6]])
l2 = np.array([[7,8],[9,10]])
print(l1+l2)
print(np.power(l1,3))
print(np.linalg.inv(l1))
print(np.sum(l1, axis = 0))
print(np.sum(l1, axis = 1))
print(np.sum(l1, axis = (0,1)))
# Out:
# [[10 12]
#  [14 16]]
# [[ 27  64]
#  [125 216]]
# [[-3.   2. ]
#  [ 2.5 -1.5]]
# [ 8 10]
# [ 7 11]
# 18

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)
# Ploteaza punctele
plt.plot(x, y, 'o')
# Adauga etichete pentru fiecare axa
plt.xlabel('x axis label')
plt.ylabel('y axis label')
# Adauga titlu
plt.title('Sine')
# Adauga legenda
plt.legend(['Sine'])
# Afiseaza figura
plt.show()

# %%
#a
images = np.zeros((9,400,600))
number = 9
for i in range(9):
    image = np.load('images/car_{}.npy'.format(i))
    images[i]=image

#b
print(np.sum(images))

#c
print(np.sum(images, axis=(1,2)))

#d
print(np.argmax(np.sum(images, axis=(1,2))))

#e
mean_image = np.mean(images, axis=0)
io.imshow(mean_image.astype(np.uint8))
io.show()
# Out:
# 269782418.0
# [28685144. 39333369. 26884392. 33514492. 29317095. 35118308. 22727807.
#  32168248. 22033563.]
# 1

# %%
#f
print(np.std(images, axis=0))
# Out:
# [[68.77661101 69.13504409 70.75483668 ... 77.82601679 77.64798694
#   76.57643644]
#  [68.50628519 68.27395794 68.39500379 ... 77.67040207 77.28734265
#   76.46462912]
#  [66.15302126 66.72848985 66.83718932 ... 77.00521066 76.63477598
#   76.18560831]
#  ...
#  [75.30677998 76.56482769 76.9156986  ... 68.23651678 67.73988012
#   69.34312609]
#  [77.55205341 78.10312904 78.74995591 ... 68.59723206 70.12334811
#   69.16485941]
#  [77.98828655 78.58533146 78.42051886 ... 69.23711272 70.36571135
#   67.241595  ]]

# %%
#g??
np.mean(images, axis = 0)
#la h printam normalizatele
